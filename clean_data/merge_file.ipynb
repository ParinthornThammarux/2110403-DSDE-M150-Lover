# %% [markdown]
# # Merge file .csv

# %%
print("f")
# Out:
# f

# %%
import pandas as pd
import glob
import os

# Folder that contains all your CSV files
folder_path = "./Scraping_data"   # <-- change this

# Find all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

print("Found CSV files:")
for f in csv_files:
    print(" -", f)

# Read and merge all CSVs
df_list = []
for file in csv_files:
    df = pd.read_csv(file)
    df_list.append(df)

merged_df = pd.concat(df_list, ignore_index=True)

# Save output
output_path = "scraping_data.csv"
merged_df.to_csv(output_path, index=False)

print(f"\nMerged {len(csv_files)} files into: {output_path}")
print("Total rows:", len(merged_df))
# Out:
# Found CSV files:
#  - ./Scraping_data\mea_power_outages_page_001_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_002_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_003_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_004_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_005_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_006_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_007_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_008_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_009_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_010_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_011_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_012_gemini.csv
#  - ./Scraping_data\mea_power_outages_page_013_gemini.csv
#
# Merged 13 files into: scraping_data.csv
# Total rows: 11355
